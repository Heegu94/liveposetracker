# %%
import json
from collections import OrderedDict
import numpy as np
from pprint import pprint

# %%
people_data = OrderedDict()
person_data = OrderedDict()

a = 1

for i in range(4):

    a = ["12"]
    b = [a, a+1, a+2, a+3]
    person_data["person_id"].append(a)
    person_data["bbox"].append(b)
    
    a += i

people_data["people"] = person_data

# Print JSON
print(json.dumps(people_data, ensure_ascii=False, indent="\t") )
# Out:
# {
# 	"people": {
# 		"person_id": [
# 			"12"
# 		],
# 		"bbox": [
# 			4,
# 			5,
# 			6,
# 			7
# 		]
# 	}
# }

# %%
people_data = OrderedDict()
person_data = OrderedDict()

person_data["person_id"] = [track.track_id]
person_data["bbox"]= [int(bbox[0]), int(bbox[1]), int(bbox[2]), int(bbox[3])]

people_data["people"] = person_data

print(json.dumps(people_data, ensure_ascii=False, indent="\t") )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-88a23e8f3ca5> in <module>
#       3 box_data = OrderedDict()
#       4
# ----> 5 person_data["person_id"] = [track.track_id]
#       6 box_data["bbox"]= [int(bbox[0]), int(bbox[1]), int(bbox[2]), int(bbox[3])]
#       7 person_data["bbox"] = box_data
#
# NameError: name 'track' is not defined

# %%
with open('D:/output/walk_tour_000000000014_keypoints.json') as file:
    data = json.load(file)
    pprint(data)
# Out:
# {'people': [{'face_keypoints_2d': [],
#              'face_keypoints_3d': [],
#              'hand_left_keypoints_2d': [],
#              'hand_left_keypoints_3d': [],
#              'hand_right_keypoints_2d': [],
#              'hand_right_keypoints_3d': [],
#              'person_id': [-1],
#              'pose_keypoints_2d': [1230.9,
#                                    335.452,
#                                    0.836402,
#                                    1244.61,
#                                    349.17,
#                                    0.915188,
#                                    1228.96,
#                                    349.174,
#                                    0.915091,
#                                    1222.99,
#                                    366.875,
#                                    0.809126,
#                                    1228.87,
#                                    370.759,
#                                    0.717616,
# ...
